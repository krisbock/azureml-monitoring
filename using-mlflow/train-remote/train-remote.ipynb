# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/MachineLearningNotebooks/how-to-use-azureml/track-and-monitor-experiments/using-mlflow/train-remote/train-remote.png)

# %% [markdown]
# ## Use MLflow with Azure Machine Learning for Remote Training Run
#
# This example shows you how to use MLflow tracking APIs together with Azure Machine Learning services for storing your metrics and artifacts, from local Notebook run. You'll learn how to:
#
#  1. Set up MLflow tracking URI so as to use Azure ML
#  2. Create experiment
#  3. Train a model on Machine Learning Compute while logging metrics and artifacts
#  4. View your experiment within your Azure ML Workspace in Azure Portal.

# %% [markdown]
# ## Prerequisites
#
# Make sure you have completed the [Configuration](../../../configuration.ipnyb) notebook to set up your Azure Machine Learning workspace and ensure other common prerequisites are met.

# %% [markdown]
# ## Set-up
#
# Check Azure ML SDK version installed on your computer, and then connect to your Workspace.

# %%
# Check core SDK version number
import azureml.core
from azureml.core import Workspace, Experiment

print("SDK version:", azureml.core.VERSION)

ws = Workspace.from_config()
# Out:
# SDK version: 1.42.0

# %% [markdown]
# Let's also create a Machine Learning Compute cluster for submitting the remote run.
#
# > Note that if you have an AzureML Data Scientist role, you will not have permission to create compute resources. Talk to your workspace or IT admin to create the compute targets described in this section, if they do not already exist.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# Choose a name for your CPU cluster
cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print("Found existing cpu-cluster")
except ComputeTargetException:
    print("Creating new cpu-cluster")
    
    # Specify the configuration for the new cluster
    compute_config = AmlCompute.provisioning_configuration(vm_size="STANDARD_D2_V2",
                                                           min_nodes=0,
                                                           max_nodes=2)

    # Create the cluster with the specified name and configuration
    cpu_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
    
    # Wait for the cluster to complete, show the output log
    cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cpu-cluster

# %% [markdown]
# ### Create Azure ML Experiment

# %% [markdown]
# The following steps show how to submit a training Python script to a cluster as an Azure ML run, while logging happens through MLflow APIs to your Azure ML Workspace. Let's first create an experiment to hold the training runs.

# %%
from azureml.core import Experiment

experiment_name = "RemoteTrain-with-mlflow-sample"
exp = Experiment(workspace=ws, name=experiment_name)

# %% [markdown]
# ### Instrument remote training script using MLflow

# %% [markdown]
# Let's use [*train_diabetes.py*](train_diabetes.py) to train a regression model against diabetes dataset as the example. Note that the training script uses mlflow.start_run() to start logging, and then logs metrics, saves the trained scikit-learn model, and saves a plot as an artifact.
#
# Run following command to view the script file. Notice the mlflow logging statements, and also notice that the script doesn't have explicit dependencies on azureml library.

# %%
training_script = 'train_diabetes.py'
with open(training_script, 'r') as f:
    print(f.read())
# Out:
# # Copyright (c) Microsoft. All rights reserved.
# # Licensed under the MIT license.
#
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn.datasets import load_diabetes
# from sklearn.linear_model import Ridge
# from sklearn.metrics import mean_squared_error
# from sklearn.model_selection import train_test_split
# import mlflow
# import mlflow.sklearn
#
# import matplotlib
# matplotlib.use('Agg')
#
# with mlflow.start_run():
#     X, y = load_diabetes(return_X_y=True)
#     columns = ['age', 'gender', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#     data = {
#         "train": {"X": X_train, "y": y_train},
#         "test": {"X": X_test, "y": y_test}}
#
#     mlflow.log_metric("Training samples", len(data['train']['X']))
#     mlflow.log_metric("Test samples", len(data['test']['X']))
#
#     # Log the algorithm parameter alpha to the run
#     mlflow.log_metric('alpha', 0.03)
#     # Create, fit, and test the scikit-learn Ridge regression model
#     regression_model = Ridge(alpha=0.03)
#     regression_model.fit(data['train']['X'], data['train']['y'])
#     preds = regression_model.predict(data['test']['X'])
#
#     # Log mean squared error
#     print('Mean Squared Error is', mean_squared_error(data['test']['y'], preds))
#     mlflow.log_metric('mse', mean_squared_error(data['test']['y'], preds))
#
#     # Save the model to the outputs directory for capture
#     mlflow.sklearn.log_model(regression_model, "model")
#
#     # Plot actuals vs predictions and save the plot within the run
#     fig = plt.figure(1)
#     idx = np.argsort(data['test']['y'])
#     plt.plot(data['test']['y'][idx], preds[idx])
#     fig.savefig("actuals_vs_predictions.png")
#     mlflow.log_artifact("actuals_vs_predictions.png")

# %% [markdown]
# ### Submit Run to Cluster
#
# Let's submit the run to cluster. When running on the remote cluster as submitted run, Azure ML sets the MLflow tracking URI to point to your Azure ML Workspace, so that the metrics and artifacts are automatically logged there.
#
# Note that you have to specify the packages your script depends on, including *azureml-mlflow* that implicitly enables the MLflow logging to Azure ML.
#
# First, create a environment with Docker enable and required package dependencies specified.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies

env = Environment(name="mlflow-env")

# Specify conda dependencies with scikit-learn and temporary pointers to mlflow extensions
cd = CondaDependencies.create(
    conda_packages=["scikit-learn", "matplotlib"],
    pip_packages=["azureml-mlflow", "pandas", "numpy"]
    )

env.python.conda_dependencies = cd

# %% [markdown]
# Next, specify a script run configuration that includes the training script, environment and CPU cluster created earlier.

# %%
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory=".",
                      script=training_script,
                      compute_target=cpu_cluster,
                      environment=env)

# %% [markdown]
# Finally, submit the run. Note that the first instance of the run typically takes longer as the Docker-based environment is created, several minutes. Subsequent runs reuse the image and are faster.

# %%
run = exp.submit(src)
run.wait_for_completion(show_output=True)
# Out:
# RunId: RemoteTrain-with-mlflow-sample_1654599681_36dcf8af
# Web View: https://ml.azure.com/runs/RemoteTrain-with-mlflow-sample_1654599681_36dcf8af?wsid=/subscriptions/3c8972d9-f541-46b2-b70b-d81baba3595d/resourcegroups/mlservices/workspaces/msmls&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2022/06/07 11:01:25 Downloading source code...
# 2022/06/07 11:01:26 Finished downloading source code
# 2022/06/07 11:01:26 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/06/07 11:01:27 Successfully set up Docker network: acb_default_network
# 2022/06/07 11:01:27 Setting up Docker configuration...
# 2022/06/07 11:01:27 Successfully set up Docker configuration
# 2022/06/07 11:01:27 Logging in to registry: msmls5213556472.azurecr.io
# 2022/06/07 11:01:29 Successfully logged into msmls5213556472.azurecr.io
# 2022/06/07 11:01:29 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/06/07 11:01:29 Scanning for dependencies...
# 2022/06/07 11:01:29 Successfully scanned dependencies
# 2022/06/07 11:01:29 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220504.v1@sha256:2fe35e84ab983f66478e9c2bc19e07121719283ada745bbb846209aca8530c8f
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220504.v1@sha256:2fe35e84ab983f66478e9c2bc19e07121719283ada745bbb846209aca8530c8f: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# d5fd17ec1767: Pulling fs layer
# c7ce926c7707: Pulling fs layer
# b6527ed3eb0f: Pulling fs layer
# 7f5e079fa1c7: Pulling fs layer
# d82d9722257b: Pulling fs layer
# 2bf166919eca: Pulling fs layer
# 0b2c99241754: Pulling fs layer
# 7aa47c332fd6: Pulling fs layer
# 374285ba860b: Pulling fs layer
# d82d9722257b: Waiting
# 2bf166919eca: Waiting
# 0b2c99241754: Waiting
# 7aa47c332fd6: Waiting
# 374285ba860b: Waiting
# 7f5e079fa1c7: Waiting
# b6527ed3eb0f: Verifying Checksum
# b6527ed3eb0f: Download complete
# d5fd17ec1767: Verifying Checksum
# d5fd17ec1767: Download complete
# 7f5e079fa1c7: Verifying Checksum
# 7f5e079fa1c7: Download complete
# 2bf166919eca: Verifying Checksum
# 2bf166919eca: Download complete
# 0b2c99241754: Verifying Checksum
# 0b2c99241754: Download complete
# c7ce926c7707: Verifying Checksum
# c7ce926c7707: Download complete
# 7aa47c332fd6: Verifying Checksum
# 7aa47c332fd6: Download complete
# 374285ba860b: Verifying Checksum
# 374285ba860b: Download complete
# d5fd17ec1767: Pull complete
# c7ce926c7707: Pull complete
# b6527ed3eb0f: Pull complete
# 7f5e079fa1c7: Pull complete
#
# d82d9722257b: Verifying Checksum
# d82d9722257b: Download complete
# d82d9722257b: Pull complete
# 2bf166919eca: Pull complete
# 0b2c99241754: Pull complete
# 7aa47c332fd6: Pull complete
# 374285ba860b: Pull complete
# Digest: sha256:2fe35e84ab983f66478e9c2bc19e07121719283ada745bbb846209aca8530c8f
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220504.v1@sha256:2fe35e84ab983f66478e9c2bc19e07121719283ada745bbb846209aca8530c8f
#  ---> 19ea84283b95
# Step 2/21 : USER root
#  ---> Running in 517ca77f1961
# Removing intermediate container 517ca77f1961
#  ---> bb3b163f3dc1
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in 81c21c4ffffc
# Removing intermediate container 81c21c4ffffc
#  ---> ae3858c68a75
# Step 4/21 : WORKDIR /
#  ---> Running in dbe8973e2d1b
# Removing intermediate container dbe8973e2d1b
#  ---> b7bc8929810f
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> c5f7f6ec86e9
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 00e5f16e2350
# Removing intermediate container 00e5f16e2350
#  ---> df95dccf82d6
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 2c736491bf31
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_73250519c0c4810028039fee15d86924 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in cdd258f0ee86
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# scikit-learn-1.0.2   | 7.6 MB    |            |   0%
# scikit-learn-1.0.2   | 7.6 MB    |            |   0%
# scikit-learn-1.0.2   | 7.6 MB    | #5         |  16%
# scikit-learn-1.0.2   | 7.6 MB    | ##7        |  28%
# scikit-learn-1.0.2   | 7.6 MB    | ###4       |  35%
# scikit-learn-1.0.2   | 7.6 MB    | ####8      |  49%
# scikit-learn-1.0.2   | 7.6 MB    | ######9    |  69%
# scikit-learn-1.0.2   | 7.6 MB    | #########  |  91%
# scikit-learn-1.0.2   | 7.6 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | ####1      |  41%
# icu-58.2             | 22.7 MB   | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# libtiff-4.2.0        | 640 KB    |            |   0%
# libtiff-4.2.0        | 640 KB    | ########## | 100%
# libtiff-4.2.0        | 640 KB    | ########## | 100%
#
# pcre-8.45            | 257 KB    |            |   0%
# pcre-8.45            | 257 KB    | ########## | 100%
#
# libffi-3.3           | 54 KB     |            |   0%
# libffi-3.3           | 54 KB     | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# wheel-0.37.1         | 31 KB     |            |   0%
# wheel-0.37.1         | 31 KB     | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | 2          |   3%
# libxcb-1.14          | 610 KB    | ########## | 100%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# python-dateutil-2.8. | 241 KB    |            |   0%
# python-dateutil-2.8. | 241 KB    | ########## | 100%
#
# scipy-1.7.3          | 21.4 MB   |            |   0%
# scipy-1.7.3          | 21.4 MB   |            |   0%
# scipy-1.7.3          | 21.4 MB   | #          |  11%
# scipy-1.7.3          | 21.4 MB   | #7         |  18%
# scipy-1.7.3          | 21.4 MB   | ##8        |  28%
# scipy-1.7.3          | 21.4 MB   | ###6       |  36%
# scipy-1.7.3          | 21.4 MB   | ####6      |  47%
# scipy-1.7.3          | 21.4 MB   | #####4     |  54%
# scipy-1.7.3          | 21.4 MB   | ######5    |  65%
# scipy-1.7.3          | 21.4 MB   | #######3   |  74%
# scipy-1.7.3          | 21.4 MB   | ########3  |  84%
# scipy-1.7.3          | 21.4 MB   | #########2 |  92%
# scipy-1.7.3          | 21.4 MB   | ########## | 100%
#
# openssl-1.1.1n       | 3.8 MB    |            |   0%
# openssl-1.1.1n       | 3.8 MB    | ########## | 100%
# openssl-1.1.1n       | 3.8 MB    | ########## | 100%
#
# tk-8.6.11            | 3.2 MB    |            |   0%
# tk-8.6.11            | 3.2 MB    | ########## | 100%
# tk-8.6.11            | 3.2 MB    | ########## | 100%
#
# libgomp-9.3.0        | 378 KB    |            |   0%
# libgomp-9.3.0        | 378 KB    | ########## | 100%
#
# libwebp-1.2.2        | 88 KB     |            |   0%
# libwebp-1.2.2        | 88 KB     | #8         |  18%
# libwebp-1.2.2        | 88 KB     | ########## | 100%
#
# ca-certificates-2022 | 132 KB    |            |   0%
# ca-certificates-2022 | 132 KB    | ########## | 100%
#
# python-3.8.12        | 22.2 MB   |            |   0%
# python-3.8.12        | 22.2 MB   | ##7        |  28%
# python-3.8.12        | 22.2 MB   | ########6  |  87%
# python-3.8.12        | 22.2 MB   | ########## | 100%
#
# six-1.16.0           | 19 KB     |            |   0%
# six-1.16.0           | 19 KB     | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | 4          |   4%
# libpng-1.6.37        | 364 KB    | ###5       |  35%
# libpng-1.6.37        | 364 KB    | ########3  |  83%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# jpeg-9e              | 273 KB    |            |   0%
# jpeg-9e              | 273 KB    | 5          |   6%
# jpeg-9e              | 273 KB    | ########## | 100%
#
# giflib-5.2.1         | 82 KB     |            |   0%
# giflib-5.2.1         | 82 KB     | ########## | 100%
#
# packaging-21.3       | 35 KB     |            |   0%
# packaging-21.3       | 35 KB     | ########## | 100%
#
# libxml2-2.9.12       | 1.3 MB    |            |   0%
# libxml2-2.9.12       | 1.3 MB    | ########## | 100%
# libxml2-2.9.12       | 1.3 MB    | ########## | 100%
#
# zlib-1.2.12          | 130 KB    |            |   0%
# zlib-1.2.12          | 130 KB    | ########## | 100%
#
# mkl-service-2.4.0    | 62 KB     |            |   0%
# mkl-service-2.4.0    | 62 KB     | ##5        |  26%
# mkl-service-2.4.0    | 62 KB     | ########## | 100%
#
# pyqt-5.9.2           | 5.5 MB    |            |   0%
# pyqt-5.9.2           | 5.5 MB    |            |   0%
# pyqt-5.9.2           | 5.5 MB    | #8         |  19%
# pyqt-5.9.2           | 5.5 MB    | ##6        |  26%
# pyqt-5.9.2           | 5.5 MB    | ####4      |  45%
# pyqt-5.9.2           | 5.5 MB    | ######4    |  65%
# pyqt-5.9.2           | 5.5 MB    | #########7 |  98%
# pyqt-5.9.2           | 5.5 MB    | ########## | 100%
#
# certifi-2021.10.8    | 156 KB    |            |   0%
# certifi-2021.10.8    | 156 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########7  |  87%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# intel-openmp-2021.4. | 8.8 MB    |            |   0%
# intel-openmp-2021.4. | 8.8 MB    | ########## | 100%
# intel-openmp-2021.4. | 8.8 MB    | ########## | 100%
#
# sip-4.19.25          | 296 KB    |            |   0%
# sip-4.19.25          | 296 KB    | 5          |   5%
# sip-4.19.25          | 296 KB    | ####8      |  49%
# sip-4.19.25          | 296 KB    | ########## | 100%
#
# pyparsing-3.0.4      | 78 KB     |            |   0%
# pyparsing-3.0.4      | 78 KB     | ########## | 100%
#
# matplotlib-base-3.5. | 7.4 MB    |            |   0%
# matplotlib-base-3.5. | 7.4 MB    |            |   0%
# matplotlib-base-3.5. | 7.4 MB    |            |   1%
# matplotlib-base-3.5. | 7.4 MB    | 1          |   2%
# matplotlib-base-3.5. | 7.4 MB    | 2          |   3%
# matplotlib-base-3.5. | 7.4 MB    | 4          |   4%
# matplotlib-base-3.5. | 7.4 MB    | 7          |   7%
# matplotlib-base-3.5. | 7.4 MB    | #          |  11%
# matplotlib-base-3.5. | 7.4 MB    | #6         |  17%
# matplotlib-base-3.5. | 7.4 MB    | ##4        |  24%
# matplotlib-base-3.5. | 7.4 MB    | ###3       |  34%
# matplotlib-base-3.5. | 7.4 MB    | ####6      |  47%
# matplotlib-base-3.5. | 7.4 MB    | ######4    |  65%
# matplotlib-base-3.5. | 7.4 MB    | ########8  |  88%
# matplotlib-base-3.5. | 7.4 MB    | ########## | 100%
#
# libgfortran4-7.5.0   | 1.3 MB    |            |   0%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
#
# qt-5.9.7             | 85.9 MB   |            |   0%
# qt-5.9.7             | 85.9 MB   |            |   0%
# qt-5.9.7             | 85.9 MB   | 1          |   1%
# qt-5.9.7             | 85.9 MB   | 2          |   3%
# qt-5.9.7             | 85.9 MB   | 3          |   4%
# qt-5.9.7             | 85.9 MB   | 5          |   5%
# qt-5.9.7             | 85.9 MB   | 8          |   8%
# qt-5.9.7             | 85.9 MB   | 9          |  10%
# qt-5.9.7             | 85.9 MB   | #2         |  13%
# qt-5.9.7             | 85.9 MB   | #4         |  15%
# qt-5.9.7             | 85.9 MB   | #7         |  18%
# qt-5.9.7             | 85.9 MB   | #9         |  20%
# qt-5.9.7             | 85.9 MB   | ##2        |  22%
# qt-5.9.7             | 85.9 MB   | ##4        |  24%
# qt-5.9.7             | 85.9 MB   | ##7        |  27%
# qt-5.9.7             | 85.9 MB   | ##9        |  30%
# qt-5.9.7             | 85.9 MB   | ###1       |  32%
# qt-5.9.7             | 85.9 MB   | ###3       |  34%
# qt-5.9.7             | 85.9 MB   | ###6       |  36%
# qt-5.9.7             | 85.9 MB   | ###8       |  38%
# qt-5.9.7             | 85.9 MB   | ####       |  40%
# qt-5.9.7             | 85.9 MB   | ####2      |  42%
# qt-5.9.7             | 85.9 MB   | ####4      |  44%
# qt-5.9.7             | 85.9 MB   | ####6      |  47%
# qt-5.9.7             | 85.9 MB   | ####8      |  49%
# qt-5.9.7             | 85.9 MB   | #####      |  51%
# qt-5.9.7             | 85.9 MB   | #####2     |  53%
# qt-5.9.7             | 85.9 MB   | #####4     |  55%
# qt-5.9.7             | 85.9 MB   | #####7     |  57%
# qt-5.9.7             | 85.9 MB   | #####9     |  59%
# qt-5.9.7             | 85.9 MB   | ######1    |  61%
# qt-5.9.7             | 85.9 MB   | ######3    |  64%
# qt-5.9.7             | 85.9 MB   | ######5    |  66%
# qt-5.9.7             | 85.9 MB   | ######8    |  68%
# qt-5.9.7             | 85.9 MB   | #######    |  70%
# qt-5.9.7             | 85.9 MB   | #######2   |  73%
# qt-5.9.7             | 85.9 MB   | #######4   |  75%
# qt-5.9.7             | 85.9 MB   | #######7   |  77%
# qt-5.9.7             | 85.9 MB   | #######9   |  79%
# qt-5.9.7             | 85.9 MB   | ########1  |  82%
# qt-5.9.7             | 85.9 MB   | ########3  |  84%
# qt-5.9.7             | 85.9 MB   | ########6  |  86%
# qt-5.9.7             | 85.9 MB   | ########8  |  88%
# qt-5.9.7             | 85.9 MB   | #########  |  91%
# qt-5.9.7             | 85.9 MB   | #########2 |  93%
# qt-5.9.7             | 85.9 MB   | #########5 |  95%
# qt-5.9.7             | 85.9 MB   | #########7 |  98%
#
# qt-5.9.7             | 85.9 MB   | ########## | 100%
# qt-5.9.7             | 85.9 MB   | ########## | 100%
#
# libwebp-base-1.2.2   | 869 KB    |            |   0%
# libwebp-base-1.2.2   | 869 KB    | 1          |   2%
# libwebp-base-1.2.2   | 869 KB    | 9          |   9%
# libwebp-base-1.2.2   | 869 KB    | ##2        |  22%
# libwebp-base-1.2.2   | 869 KB    | ####       |  41%
# libwebp-base-1.2.2   | 869 KB    | ######     |  61%
# libwebp-base-1.2.2   | 869 KB    | ########8  |  88%
# libwebp-base-1.2.2   | 869 KB    | ########## | 100%
#
# ncurses-6.3          | 1.0 MB    |            |   0%
# ncurses-6.3          | 1.0 MB    | ########## | 100%
# ncurses-6.3          | 1.0 MB    | ########## | 100%
#
# lcms2-2.12           | 396 KB    |            |   0%
# lcms2-2.12           | 396 KB    | 4          |   4%
# lcms2-2.12           | 396 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 7.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
#
# fonttools-4.25.0     | 674 KB    |            |   0%
# fonttools-4.25.0     | 674 KB    | 2          |   2%
# fonttools-4.25.0     | 674 KB    | ########## | 100%
# fonttools-4.25.0     | 674 KB    | ########## | 100%
#
# mkl-2021.4.0         | 219.1 MB  |            |   0%
# mkl-2021.4.0         | 219.1 MB  | 4          |   5%
# mkl-2021.4.0         | 219.1 MB  | #          |  11%
# mkl-2021.4.0         | 219.1 MB  | #7         |  17%
# mkl-2021.4.0         | 219.1 MB  | ##3        |  23%
# mkl-2021.4.0         | 219.1 MB  | ##9        |  30%
# mkl-2021.4.0         | 219.1 MB  | ###5       |  36%
# mkl-2021.4.0         | 219.1 MB  | ####1      |  41%
# mkl-2021.4.0         | 219.1 MB  | ####6      |  47%
# mkl-2021.4.0         | 219.1 MB  | #####2     |  52%
# mkl-2021.4.0         | 219.1 MB  | #####8     |  59%
# mkl-2021.4.0         | 219.1 MB  | ######5    |  65%
# mkl-2021.4.0         | 219.1 MB  | #######1   |  72%
# mkl-2021.4.0         | 219.1 MB  | #######7   |  78%
# mkl-2021.4.0         | 219.1 MB  | ########4  |  84%
# mkl-2021.4.0         | 219.1 MB  | #########  |  91%
# mkl-2021.4.0         | 219.1 MB  | #########7 |  97%
#
# mkl-2021.4.0         | 219.1 MB  | ########## | 100%
#
# zstd-1.4.5           | 716 KB    |            |   0%
# zstd-1.4.5           | 716 KB    | ########## | 100%
# zstd-1.4.5           | 716 KB    | ########## | 100%
#
# pillow-9.0.1         | 716 KB    |            |   0%
# pillow-9.0.1         | 716 KB    | ########## | 100%
# pillow-9.0.1         | 716 KB    | ########## | 100%
#
# ld_impl_linux-64-2.3 | 637 KB    |            |   0%
# ld_impl_linux-64-2.3 | 637 KB    | ########## | 100%
# ld_impl_linux-64-2.3 | 637 KB    | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ####7      |  47%
# glib-2.56.2          | 5.0 MB    | ######1    |  61%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# libuuid-1.0.3        | 18 KB     |            |   0%
# libuuid-1.0.3        | 18 KB     | ########7  |  87%
# libuuid-1.0.3        | 18 KB     | ########## | 100%
#
# munkres-1.1.4        | 13 KB     |            |   0%
# munkres-1.1.4        | 13 KB     | ########## | 100%
# munkres-1.1.4        | 13 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | 1          |   2%
# gst-plugins-base-1.1 | 6.3 MB    | 4          |   4%
# gst-plugins-base-1.1 | 6.3 MB    | 7          |   8%
# gst-plugins-base-1.1 | 6.3 MB    | #1         |  11%
# gst-plugins-base-1.1 | 6.3 MB    | #6         |  16%
# gst-plugins-base-1.1 | 6.3 MB    | ##4        |  24%
# gst-plugins-base-1.1 | 6.3 MB    | ###4       |  35%
# gst-plugins-base-1.1 | 6.3 MB    | ####7      |  48%
# gst-plugins-base-1.1 | 6.3 MB    | ######3    |  63%
# gst-plugins-base-1.1 | 6.3 MB    | ########7  |  88%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# setuptools-61.2.0    | 1.3 MB    |            |   0%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
#
# brotli-1.0.9         | 402 KB    |            |   0%
# brotli-1.0.9         | 402 KB    | 3          |   4%
# brotli-1.0.9         | 402 KB    | ########## | 100%
#
# sqlite-3.38.2        | 1.5 MB    |            |   0%
# sqlite-3.38.2        | 1.5 MB    | ########## | 100%
# sqlite-3.38.2        | 1.5 MB    | ########## | 100%
#
# joblib-1.1.0         | 211 KB    |            |   0%
# joblib-1.1.0         | 211 KB    | 7          |   8%
# joblib-1.1.0         | 211 KB    | ######8    |  68%
# joblib-1.1.0         | 211 KB    | ########## | 100%
#
# expat-2.4.4          | 211 KB    |            |   0%
# expat-2.4.4          | 211 KB    | 7          |   8%
# expat-2.4.4          | 211 KB    | ##2        |  23%
# expat-2.4.4          | 211 KB    | ######8    |  68%
# expat-2.4.4          | 211 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# readline-8.1.2       | 423 KB    |            |   0%
# readline-8.1.2       | 423 KB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | 2          |   3%
# dbus-1.13.18         | 586 KB    | ########## | 100%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# mkl_random-1.2.2     | 341 KB    |            |   0%
# mkl_random-1.2.2     | 341 KB    | 4          |   5%
# mkl_random-1.2.2     | 341 KB    | ###7       |  38%
# mkl_random-1.2.2     | 341 KB    | ########## | 100%
# mkl_random-1.2.2     | 341 KB    | ########## | 100%
#
# numpy-1.21.5         | 10 KB     |            |   0%
# numpy-1.21.5         | 10 KB     | ########## | 100%
# numpy-1.21.5         | 10 KB     | ########## | 100%
#
# fontconfig-2.13.1    | 299 KB    |            |   0%
# fontconfig-2.13.1    | 299 KB    | 5          |   5%
# fontconfig-2.13.1    | 299 KB    | #6         |  16%
# fontconfig-2.13.1    | 299 KB    | ####8      |  48%
# fontconfig-2.13.1    | 299 KB    | ######9    |  69%
# fontconfig-2.13.1    | 299 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# cycler-0.11.0        | 12 KB     |            |   0%
# cycler-0.11.0        | 12 KB     | ########## | 100%
# cycler-0.11.0        | 12 KB     | ########## | 100%
#
# matplotlib-3.5.1     | 28 KB     |            |   0%
# matplotlib-3.5.1     | 28 KB     | #####7     |  58%
# matplotlib-3.5.1     | 28 KB     | ########## | 100%
#
# pip-21.2.4           | 2.0 MB    |            |   0%
# pip-21.2.4           | 2.0 MB    | ########## | 100%
# pip-21.2.4           | 2.0 MB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
#
# lz4-c-1.9.3          | 216 KB    |            |   0%
# lz4-c-1.9.3          | 216 KB    | ########## | 100%
#
# mkl_fft-1.3.1        | 200 KB    |            |   0%
# mkl_fft-1.3.1        | 200 KB    | ########## | 100%
#
# numpy-base-1.21.5    | 6.1 MB    |            |   0%
# numpy-base-1.21.5    | 6.1 MB    | ########## | 100%
# numpy-base-1.21.5    | 6.1 MB    | ########## | 100%
#
# freetype-2.11.0      | 943 KB    |            |   0%
# freetype-2.11.0      | 943 KB    | 1          |   2%
# freetype-2.11.0      | 943 KB    | ###9       |  39%
# freetype-2.11.0      | 943 KB    | #####9     |  59%
# freetype-2.11.0      | 943 KB    | ########## | 100%
# freetype-2.11.0      | 943 KB    | ########## | 100%
#
# tornado-6.1          | 648 KB    |            |   0%
# tornado-6.1          | 648 KB    | 2          |   2%
# tornado-6.1          | 648 KB    | ########## | 100%
# tornado-6.1          | 648 KB    | ########## | 100%
#
# kiwisolver-1.3.2     | 87 KB     |            |   0%
# kiwisolver-1.3.2     | 87 KB     | #8         |  18%
# kiwisolver-1.3.2     | 87 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_73250519c0c4810028039fee15d86924/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.skz51gz8.requirements.txt']
# Pip subprocess output:
# Collecting azureml-mlflow~=1.42.0
#   Downloading azureml_mlflow-1.42.0-py3-none-any.whl (50 kB)
# Collecting pandas
#   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
# Requirement already satisfied: numpy in /azureml-envs/azureml_73250519c0c4810028039fee15d86924/lib/python3.8/site-packages (from -r /azureml-environment-setup/condaenv.skz51gz8.requirements.txt (line 3)) (1.21.5)
# Collecting numpy
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
# Collecting mlflow-skinny
#   Downloading mlflow_skinny-1.26.1-py3-none-any.whl (3.5 MB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting azureml-core~=1.42.0
#   Downloading azureml_core-1.42.0-py3-none-any.whl (2.7 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /azureml-envs/azureml_73250519c0c4810028039fee15d86924/lib/python3.8/site-packages (from pandas->-r /azureml-environment-setup/condaenv.skz51gz8.requirements.txt (line 2)) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: packaging<22.0,>=20.0 in /azureml-envs/azureml_73250519c0c4810028039fee15d86924/lib/python3.8/site-packages (from azureml-core~=1.42.0->azureml-mlflow~=1.42.0->-r /azureml-environment-setup/condaenv.skz51gz8.requirements.txt (line 1)) (21.3)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.2-py2.py3-none-any.whl (26 kB)
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-containerregistry<10,>=8.2.0
#   Downloading azure_mgmt_containerregistry-9.1.0-py3-none-any.whl (1.1 MB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting azure-mgmt-resource<=21.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.0.0-py3-none-any.whl (2.3 MB)
# Collecting azure-mgmt-storage<=20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-core<=1.22.1
#   Downloading azure_core-1.22.1-py3-none-any.whl (178 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0
#   Downloading cryptography-36.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
# Collecting urllib3<=1.26.9,>=1.23
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.2-py3-none-any.whl (15 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting jmespath<=1.0.0
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.18.0-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_73250519c0c4810028039fee15d86924/lib/python3.8/site-packages (from azure-core<=1.22.1->azureml-core~=1.42.0->azureml-mlflow~=1.42.0->-r /azureml-environment-setup/condaenv.skz51gz8.requirements.txt (line 1)) (1.16.0)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (446 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
# Collecting pygments
#   Downloading Pygments-2.12.0-py3-none-any.whl (1.1 MB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_73250519c0c4810028039fee15d86924/lib/python3.8/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.42.0->azureml-mlflow~=1.42.0->-r /azureml-environment-setup/condaenv.skz51gz8.requirements.txt (line 1)) (2021.10.8)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /azureml-envs/azureml_73250519c0c4810028039fee15d86924/lib/python3.8/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.42.0->azureml-mlflow~=1.42.0->-r /azureml-environment-setup/condaenv.skz51gz8.requirements.txt (line 1)) (3.0.4)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.2-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (62 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting click>=7.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.16.6.tar.gz (62 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-4.21.1-cp37-abi3-manylinux2014_x86_64.whl (407 kB)
# Collecting importlib-metadata!=4.7.0,>=3.7.0
#   Downloading importlib_metadata-4.11.4-py3-none-any.whl (18 kB)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Building wheels for collected packages: databricks-cli
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.6-py3-none-any.whl size=112626 sha256=138b2cddafab019167ef62abb47b37755d2153d5f76d908ccfac401036dab5f7
#   Stored in directory: /root/.cache/pip/wheels/76/3a/2f/8a3d92bc72a413217b5c8649e2044d7161cacbe06e014361a3
# Successfully built databricks-cli
# Installing collected packages: urllib3, pycparser, idna, charset-normalizer, requests, oauthlib, cffi, requests-oauthlib, PyJWT, isodate, cryptography, smmap, msrest, azure-core, adal, zipp, websocket-client, tabulate, pyyaml, PySocks, pyopenssl, pynacl, pygments, pyasn1, portalocker, msrestazure, msal, jmespath, jeepney, gitdb, click, bcrypt, backports.weakref, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pytz, protobuf, pkginfo, pathspec, paramiko, ndg-httpsclient, msal-extensions, knack, jsonpickle, importlib-metadata, humanfriendly, gitpython, entrypoints, docker, databricks-cli, contextlib2, cloudpickle, backports.tempfile, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, numpy, mlflow-skinny, azureml-core, pandas, azureml-mlflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed PyJWT-2.4.0 PySocks-1.7.1 SecretStorage-3.3.2 adal-1.2.7 argcomplete-2.0.0 azure-common-1.1.28 azure-core-1.22.1 azure-graphrbac-0.61.1 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-9.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-21.0.0 azure-mgmt-storage-20.0.0 azureml-core-1.42.0 azureml-mlflow-1.42.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.2 cffi-1.15.0 charset-normalizer-2.0.12 click-8.1.3 cloudpickle-2.1.0 contextlib2-21.6.0 cryptography-36.0.2 databricks-cli-0.16.6 docker-5.0.3 entrypoints-0.4 gitdb-4.0.9 gitpython-3.1.27 humanfriendly-10.0 idna-3.3 importlib-metadata-4.11.4 isodate-0.6.1 jeepney-0.8.0 jmespath-1.0.0 jsonpickle-2.2.0 knack-0.9.0 mlflow-skinny-1.26.1 msal-1.18.0 msal-extensions-1.0.0 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.22.4 oauthlib-3.2.0 pandas-1.4.2 paramiko-2.11.0 pathspec-0.9.0 pkginfo-1.8.2 portalocker-2.4.0 protobuf-4.21.1 pyasn1-0.4.8 pycparser-2.21 pygments-2.12.0 pynacl-1.5.0 pyopenssl-22.0.0 pytz-2022.1 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 smmap-5.0.0 tabulate-0.8.9 urllib3-1.26.9 websocket-client-1.3.2 zipp-3.8.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_73250519c0c4810028039fee15d86924
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container cdd258f0ee86
#  ---> 5dc8ad1e37e0
# Step 9/21 : ENV PATH /azureml-envs/azureml_73250519c0c4810028039fee15d86924/bin:$PATH
#  ---> Running in d9388bfdf87c
# Removing intermediate container d9388bfdf87c
#  ---> 3f810c1f9547
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 70ca116ef532
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in e315be071ef9
# Copying environment context
# Removing intermediate container e315be071ef9
#  ---> 9d9d8c89fa95
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 9cc3ff8d8321
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_73250519c0c4810028039fee15d86924
#  ---> Running in 8fbfe5ce3d64
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 8fbfe5ce3d64
#  ---> 9a4c9cd93627
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_73250519c0c4810028039fee15d86924
#  ---> Running in c2f788af8f09
# Removing intermediate container c2f788af8f09
#  ---> 8dc1131528e0
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_73250519c0c4810028039fee15d86924/lib:$LD_LIBRARY_PATH
#  ---> Running in 8a6665b8dd62
# Removing intermediate container 8a6665b8dd62
#  ---> 9bc2e7467237
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_73250519c0c4810028039fee15d86924 CONDA_PREFIX=/azureml-envs/azureml_73250519c0c4810028039fee15d86924
#  ---> Running in 71a8d26961c4
# Removing intermediate container 71a8d26961c4
#  ---> 7a9f99db24f4
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 3c7ca4fe0e51
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in a02060ffcbce
# Removing intermediate container a02060ffcbce
#  ---> 53b2be8636dd
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 30d48eea0928
# Removing intermediate container 30d48eea0928
#  ---> c3e2cf231593
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in abcf06c435dc
# Removing intermediate container abcf06c435dc
#  ---> 380f5415874d
# Step 21/21 : CMD ["bash"]
#  ---> Running in ac1828a3fcf4
# Removing intermediate container ac1828a3fcf4
#  ---> 9b3e33113024
# Successfully built 9b3e33113024
# Successfully tagged msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5:latest
# Successfully tagged msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5:1
# 2022/06/07 11:07:00 Successfully executed container: acb_step_0
# 2022/06/07 11:07:00 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/06/07 11:07:00 Pushing image: msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5:1, attempt 1
# The push refers to repository [msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5]
# 8e636a8ebafd: Preparing
# 81dae89511b1: Preparing
# 4832a1ef9bd9: Preparing
# 8d6c358174f4: Preparing
# 19277cb038c8: Preparing
# eadb48da9b34: Preparing
# a57392dc2116: Preparing
# 0b9f00dfde09: Preparing
# 158f74fb2943: Preparing
# 5727555db5d0: Preparing
# 18b4fde8308e: Preparing
# 663125f79c4b: Preparing
# ad5920080d46: Preparing
# 19487f85ddb1: Preparing
# c5ce9d6a5db1: Preparing
# bec9dbaf8a3a: Preparing
# 907444abbcbc: Preparing
# f1821f1b2d16: Preparing
# bf8cedc62fb3: Preparing
# eadb48da9b34: Waiting
# a57392dc2116: Waiting
# 0b9f00dfde09: Waiting
# 158f74fb2943: Waiting
# 5727555db5d0: Waiting
# 18b4fde8308e: Waiting
# 663125f79c4b: Waiting
# ad5920080d46: Waiting
# 19487f85ddb1: Waiting
# c5ce9d6a5db1: Waiting
# bec9dbaf8a3a: Waiting
# 907444abbcbc: Waiting
# f1821f1b2d16: Waiting
# bf8cedc62fb3: Waiting
# 19277cb038c8: Pushed
# 8e636a8ebafd: Pushed
# 81dae89511b1: Pushed
# 8d6c358174f4: Pushed
# a57392dc2116: Pushed
# 4832a1ef9bd9: Pushed
# 158f74fb2943: Pushed
# 0b9f00dfde09: Pushed
# 5727555db5d0: Pushed
# 18b4fde8308e: Pushed
# 663125f79c4b: Pushed
# ad5920080d46: Pushed
# 19487f85ddb1: Pushed
# bec9dbaf8a3a: Pushed
# 907444abbcbc: Pushed
# c5ce9d6a5db1: Pushed
# bf8cedc62fb3: Pushed
# f1821f1b2d16: Pushed
# eadb48da9b34: Pushed
# 1: digest: sha256:36293a01c5a715cbd4498e45abb987ef75669c1841b23717886dbc72f73d72b9 size: 4306
# 2022/06/07 11:08:53 Successfully pushed image: msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5:1
# 2022/06/07 11:08:53 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/06/07 11:08:53 Pushing image: msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5:latest, attempt 1
# The push refers to repository [msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5]
# 8e636a8ebafd: Preparing
# 81dae89511b1: Preparing
# 4832a1ef9bd9: Preparing
# 8d6c358174f4: Preparing
# 19277cb038c8: Preparing
# eadb48da9b34: Preparing
# a57392dc2116: Preparing
# 0b9f00dfde09: Preparing
# 158f74fb2943: Preparing
# 5727555db5d0: Preparing
# 18b4fde8308e: Preparing
# 663125f79c4b: Preparing
# ad5920080d46: Preparing
# 19487f85ddb1: Preparing
# c5ce9d6a5db1: Preparing
# bec9dbaf8a3a: Preparing
# 907444abbcbc: Preparing
# f1821f1b2d16: Preparing
# bf8cedc62fb3: Preparing
# 18b4fde8308e: Waiting
# 663125f79c4b: Waiting
# ad5920080d46: Waiting
# 19487f85ddb1: Waiting
# c5ce9d6a5db1: Waiting
# eadb48da9b34: Waiting
# bec9dbaf8a3a: Waiting
# a57392dc2116: Waiting
# 0b9f00dfde09: Waiting
# 907444abbcbc: Waiting
# 158f74fb2943: Waiting
# 5727555db5d0: Waiting
# f1821f1b2d16: Waiting
# bf8cedc62fb3: Waiting
# 4832a1ef9bd9: Layer already exists
# 19277cb038c8: Layer already exists
# 8e636a8ebafd: Layer already exists
# a57392dc2116: Layer already exists
# eadb48da9b34: Layer already exists
# 158f74fb2943: Layer already exists
# 0b9f00dfde09: Layer already exists
# 5727555db5d0: Layer already exists
# 663125f79c4b: Layer already exists
# 18b4fde8308e: Layer already exists
# ad5920080d46: Layer already exists
# 19487f85ddb1: Layer already exists
# bec9dbaf8a3a: Layer already exists
# 907444abbcbc: Layer already exists
# c5ce9d6a5db1: Layer already exists
# f1821f1b2d16: Layer already exists
# 8d6c358174f4: Layer already exists
# 81dae89511b1: Layer already exists
# bf8cedc62fb3: Layer already exists
# latest: digest: sha256:36293a01c5a715cbd4498e45abb987ef75669c1841b23717886dbc72f73d72b9 size: 4306
# 2022/06/07 11:09:00 Successfully pushed image: msmls5213556472.azurecr.io/azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5:latest
# 2022/06/07 11:09:00 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 331.254917)
# 2022/06/07 11:09:00 Populating digests for step ID: acb_step_0...
# 2022/06/07 11:09:01 Successfully populated digests for step ID: acb_step_0
# 2022/06/07 11:09:01 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 113.544717)
# 2022/06/07 11:09:01 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.934887)
# 2022/06/07 11:09:01 The following dependencies were found:
# 2022/06/07 11:09:01
# - image:
#     registry: msmls5213556472.azurecr.io
#     repository: azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5
#     tag: latest
#     digest: sha256:36293a01c5a715cbd4498e45abb987ef75669c1841b23717886dbc72f73d72b9
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220504.v1
#     digest: sha256:2fe35e84ab983f66478e9c2bc19e07121719283ada745bbb846209aca8530c8f
#   git: {}
# - image:
#     registry: msmls5213556472.azurecr.io
#     repository: azureml/azureml_16f36e36cfd3eb4b4ea60b43140659b5
#     tag: "1"
#     digest: sha256:36293a01c5a715cbd4498e45abb987ef75669c1841b23717886dbc72f73d72b9
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220504.v1
#     digest: sha256:2fe35e84ab983f66478e9c2bc19e07121719283ada745bbb846209aca8530c8f
#   git: {}
#
#
# Run ID: cr4g was successful after 7m37s
#
# Execution Summary
# =================
# RunId: RemoteTrain-with-mlflow-sample_1654599681_36dcf8af
# Web View: https://ml.azure.com/runs/RemoteTrain-with-mlflow-sample_1654599681_36dcf8af?wsid=/subscriptions/3c8972d9-f541-46b2-b70b-d81baba3595d/resourcegroups/mlservices/workspaces/msmls&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# {'runId': 'RemoteTrain-with-mlflow-sample_1654599681_36dcf8af',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2022-06-07T11:15:47.162174Z',
#  'endTimeUtc': '2022-06-07T11:16:45.228751Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlctrain',
#   'ContentSnapshotId': '5f5683d4-cbde-46ed-af20-97dbe8aa6ac0',
#   'azureml.git.repository_uri': 'https://github.com/krisbock/azureml-monitoring.git',
#   'mlflow.source.git.repoURL': 'https://github.com/krisbock/azureml-monitoring.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': '0efc10396cdc4a5f4a72322a5f9752e6a66ed381',
#   'mlflow.source.git.commit': '0efc10396cdc4a5f4a72322a5f9752e6a66ed381',
#   'azureml.git.dirty': 'False',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train_diabetes.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'mlflow-env',
#    'version': 'Autosave_2022-06-07T11:01:20Z_6c281537',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.8.12',
#       {'pip': ['azureml-mlflow~=1.42.0', 'pandas', 'numpy']},
#       'scikit-learn',
#       'matplotlib'],
#      'channels': ['anaconda', 'conda-forge']},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220504.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=2XuX3XtKgg4kGKbr%2F0fIB5YMlW2wBiBnvEaiSD2JHZs%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T01%3A17%3A09Z&ske=2022-06-08T09%3A27%3A09Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A35Z&se=2022-06-07T19%3A17%3A35Z&sp=r',
#   'user_logs/std_log.txt': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/user_logs/std_log.txt?sv=2019-07-07&sr=b&sig=qP21Kb6gnCxutcgp0N6GX5zL11igm7PSXCpUyDgJT5Y%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A07%3A25Z&ske=2022-06-08T18%3A17%3A25Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A37Z&se=2022-06-07T19%3A17%3A37Z&sp=r',
#   'system_logs/cs_capability/cs-capability.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/cs_capability/cs-capability.log?sv=2019-07-07&sr=b&sig=7F%2F5tjYsj3TeMoVCwtRtUjeIFf6hTLhzO5AVLBf4fA8%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A41%3A43Z&ske=2022-06-08T18%3A51%3A43Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A38Z&se=2022-06-07T19%3A17%3A38Z&sp=r',
#   'system_logs/hosttools_capability/hosttools-capability.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/hosttools_capability/hosttools-capability.log?sv=2019-07-07&sr=b&sig=8%2Bja68Wtql%2Fdn5PEqbL66dY3Dx5ytU96x5j6%2BA%2BB9ds%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A41%3A43Z&ske=2022-06-08T18%3A51%3A43Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A38Z&se=2022-06-07T19%3A17%3A38Z&sp=r',
#   'system_logs/lifecycler/execution-wrapper.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/lifecycler/execution-wrapper.log?sv=2019-07-07&sr=b&sig=CMZutPI1xOGnBL0xULbQQfVH7pnCfvWpEKsTt8Oz9VE%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A41%3A43Z&ske=2022-06-08T18%3A51%3A43Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A38Z&se=2022-06-07T19%3A17%3A38Z&sp=r',
#   'system_logs/lifecycler/lifecycler.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/lifecycler/lifecycler.log?sv=2019-07-07&sr=b&sig=CkU68u9qmu%2FlEdbVOonKsiKXt77bKi6e5cRF97JTk68%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A41%3A43Z&ske=2022-06-08T18%3A51%3A43Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A38Z&se=2022-06-07T19%3A17%3A38Z&sp=r'},
#  'submittedBy': 'Kris Bock'}

# %% [markdown]
# You can navigate to your Azure ML Workspace at Azure Portal to view the run metrics and artifacts.

# %%
run
# Out:
# Run(Experiment: RemoteTrain-with-mlflow-sample,
# Id: RemoteTrain-with-mlflow-sample_1654599681_36dcf8af,
# Type: azureml.scriptrun,
# Status: Completed)

# %% [markdown]
# You can also get the metrics and bring them to your local notebook, and view the details of the run.

# %%
run.get_metrics()
# Out:
# {'Training samples': 353.0,
#  'Test samples': 89.0,
#  'alpha': 0.03,
#  'mse': 3424.900315896017}

# %%
run.get_details()
# Out:
# {'runId': 'RemoteTrain-with-mlflow-sample_1654599681_36dcf8af',
#  'target': 'cpu-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2022-06-07T11:15:47.162174Z',
#  'endTimeUtc': '2022-06-07T11:16:45.228751Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlctrain',
#   'ContentSnapshotId': '5f5683d4-cbde-46ed-af20-97dbe8aa6ac0',
#   'azureml.git.repository_uri': 'https://github.com/krisbock/azureml-monitoring.git',
#   'mlflow.source.git.repoURL': 'https://github.com/krisbock/azureml-monitoring.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': '0efc10396cdc4a5f4a72322a5f9752e6a66ed381',
#   'mlflow.source.git.commit': '0efc10396cdc4a5f4a72322a5f9752e6a66ed381',
#   'azureml.git.dirty': 'False',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train_diabetes.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpu-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'mlflow-env',
#    'version': 'Autosave_2022-06-07T11:01:20Z_6c281537',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.8.12',
#       {'pip': ['azureml-mlflow~=1.42.0', 'pandas', 'numpy']},
#       'scikit-learn',
#       'matplotlib'],
#      'channels': ['anaconda', 'conda-forge']},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220504.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=2XuX3XtKgg4kGKbr%2F0fIB5YMlW2wBiBnvEaiSD2JHZs%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T01%3A17%3A09Z&ske=2022-06-08T09%3A27%3A09Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A35Z&se=2022-06-07T19%3A17%3A35Z&sp=r',
#   'user_logs/std_log.txt': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/user_logs/std_log.txt?sv=2019-07-07&sr=b&sig=hMoKUJrYhNpomWWLls4IiBGzKZ7OEn2nngLTIIdouWw%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T11%3A06%3A41Z&ske=2022-06-08T19%3A16%3A41Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A43Z&se=2022-06-07T19%3A17%3A43Z&sp=r',
#   'system_logs/cs_capability/cs-capability.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/cs_capability/cs-capability.log?sv=2019-07-07&sr=b&sig=jciShaGxcC2XItYtogqbZwuPRGQHmeDcJzsv6vCnOfw%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A07%3A25Z&ske=2022-06-08T18%3A17%3A25Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A43Z&se=2022-06-07T19%3A17%3A43Z&sp=r',
#   'system_logs/hosttools_capability/hosttools-capability.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/hosttools_capability/hosttools-capability.log?sv=2019-07-07&sr=b&sig=GnOPvOnKvURJpXTAuKZYNpkBQpj%2BNQ6icGLoP%2FDG4Wk%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A07%3A25Z&ske=2022-06-08T18%3A17%3A25Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A43Z&se=2022-06-07T19%3A17%3A43Z&sp=r',
#   'system_logs/lifecycler/execution-wrapper.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/lifecycler/execution-wrapper.log?sv=2019-07-07&sr=b&sig=LHq%2BHsraUQ1RHAP4o2olhWqf9ecfOnQr7CYUkrsPxkE%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A07%3A25Z&ske=2022-06-08T18%3A17%3A25Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A43Z&se=2022-06-07T19%3A17%3A43Z&sp=r',
#   'system_logs/lifecycler/lifecycler.log': 'https://msmls9093850258.blob.core.windows.net/azureml/ExperimentRun/dcid.RemoteTrain-with-mlflow-sample_1654599681_36dcf8af/system_logs/lifecycler/lifecycler.log?sv=2019-07-07&sr=b&sig=bvTxU9zGM7ZX5RNvFiJvGNNPj1ueOX7J%2FaCuLmlZW%2B8%3D&skoid=533f9b41-fe01-444e-be02-dac3fb70c11c&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-07T10%3A07%3A25Z&ske=2022-06-08T18%3A17%3A25Z&sks=b&skv=2019-07-07&st=2022-06-07T11%3A07%3A43Z&se=2022-06-07T19%3A17%3A43Z&sp=r'},
#  'submittedBy': 'Kris Bock'}

# %% [markdown]
# ### Next steps
#
#  * [Deploy the model as a web service](../deploy-model/deploy-model.ipynb)
#  * [Learn more about Azure Machine Learning compute options](https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-set-up-training-targets)
